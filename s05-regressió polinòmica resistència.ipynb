# %%
#Regressió polinòmica resistència

# %%
import numpy
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
conc = [1, 1.5, 2, 3, 4, 4.5, 5, 5.5, 6, 6.5, 7, 8, 9, 10, 11, 12, 13, 14, 15]
resis = [6.3, 11.1, 20, 24, 26.1, 30, 33.8, 34, 38.1, 39.9, 42, 46.1, 53.1, 52, 52.5, 48, 42.8, 27.8, 21.9]

# %%
plt.scatter(x, y)

# %%
x = conc
y = resis

# %%
plt.scatter(x, y)
# Calcul del model Polinominal de Numpy. Graus d'ajustament del polinomi = 3
fun_model = numpy.poly1d(numpy.polyfit(x, y, 3))
fun_model2 = numpy.poly1d(numpy.polyfit(x, y, 4))

# ----- dbuixar linea de model
linea_x = numpy.linspace(1, 15, 100)
plt.plot(linea_x, fun_model(linea_x))
plt.plot(linea_x, fun_model2(linea_x))

plt.show()
print(r2_score(y, fun_model(x)))
print(r2_score(y, fun_model2(x)))
# Out:
# 0.9706642461170235
# 0.9735953954982567
