# %% [markdown]
# ### REGRESIO MULTIPLE

# %%
# Exemple regressió MÚLTIPLE amb w3schools
# https://www.w3schools.com/python/python_ml_multiple_regression.asp
# Predicció de les emisions de CO2 en funció de "MULTIPLES" variables

# %%
import pandas
import matplotlib.pyplot as plt

df = pandas.read_csv("./dat/cars_co2.csv")

#-------------------- Scatter de la variable pes 
plt.xlabel('Pes i volum del Automòbil')
plt.ylabel('CO2')
plt.scatter(df['Weight'], df['CO2'], marker='o')
plt.scatter(df['Volume'], df['CO2'], marker='s')
plt.show()

# %%
import pandas
from sklearn import linear_model

df = pandas.read_csv("./dat/cars_co2.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

#predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3:
predictedCO2 = regr.predict([[2300, 1300]])

print(predictedCO2)
# Out:
# [107.2087328]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
dir(regr)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_intercept',
#  '_validate_data',
#  '_validate_params',
#  'coef_',
#  'copy_X',
#  'feature_names_in_',
#  'fit',
#  'fit_intercept',
#  'get_params',
#  'intercept_',
#  'n_features_in_',
#  'n_jobs',
#  'positive',
# ...

# %%
regr.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Weight', 'Volume'], dtype=object),
#  'n_features_in_': 2,
#  'coef_': array([0.00755095, 0.00780526]),
#  'rank_': 2,
#  'singular_': array([2576.85823153,  840.94972047]),
#  'intercept_': 79.69471929115939}

# %%
# Escala les dues variables i fes la predicció per 2300 i 1300 / i per 3300 i 1300

# %%
predictedCO2 = regr.predict([[2300, 1300]])
print(predictedCO2)
# Out:
# [107.2087328]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Mostra l'escatter de les dues variables escalades

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
df = pandas.read_csv("./dat/cars_co2.csv")
X = df[['Weight', 'Volume']]
scaledX = scale.fit_transform(X)
regr.fit(scaledX,y)
#print(scaledX)
# Out:
# LinearRegression()

# %%
# PRACTICA 1 - 1
# 1. Multiple scatter plots in single plot in Pandas using Matplotlib

# %%
plt.xlabel("Pes i volum del Automòbil")
plt.ylabel("CO2")
plt.scatter(scaledX[:,0],y,marker='o')
plt.scatter(scaledX[:,1],y,marker='s')
plt.show()

# %%
scaledX[0]
# Out:
# array([-2.10389253, -1.59336644])

# %%
# PRACTICA 1 - 2
# 2. Analysing medical cost
scaled = scale.transform([[2300, 1300]])
predictedCO2 = regr.predict([scaled[0]])
print(predictedCO2)
# Out:
# [107.2087328]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Medical cost dataset.
df=pd.read_csv('./dat/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Finding correlation between Age and Charges by ploting a scatter plot.
plt.title('Relation between Age and Charges')
sns.scatterplot(x=df['age'],y=df['charges'])
plt.show()
plt.title('Regression between Age and Charges')
sns.regplot(x=df['age'],y=df['charges'])
plt.show()

# %%
#Finding correlation between BMI and Charges by ploting a scatter plot.
plt.title('Relation between BMI and Charges')
sns.scatterplot(x=df['bmi'],y=df['charges'])
plt.show()
plt.title('Relation between BMI and Charges')
sns.regplot(x=df['bmi'],y=df['charges'])
plt.show()

# %%
#Finding correlation between Smokers and Charges by ploting a scatter plot.
sns.scatterplot(x=df['bmi'], y=df['charges'], hue=df['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=df)

# %%
sns.swarmplot(x=df['smoker'],y=df['charges'])
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Finding correlation between Children and Charges by ploting a scatter plot.
plt.figure(figsize=(14,6))
plt.title('Relation between Age and Charges')
#sns.regplot(x=df['children'],y=df['charges'])
sns.barplot(x=df['children'], y=df['charges'])
# Out:
# <Axes: title={'center': 'Relation between Age and Charges'}, xlabel='children', ylabel='charges'>

# %%
#Finding correlation between Sex and Charges by ploting a scatter plot.
sns.swarmplot(x=df['sex'],y=df['charges'])
plt.show()
sns.scatterplot(x=df['bmi'], y=df['charges'], hue=df['sex'])
plt.show()
sns.barplot(x=df['sex'], y=df['charges'])
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 30.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 26.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Finding correlation between Region and Charges by ploting a scatter plot.
sns.swarmplot(x=df['region'],y=df['charges'])
plt.show()
sns.barplot(x=df['region'], y=df['charges'])
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 21.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 23.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 21.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## ENTRENAMENT

# %%
import numpy
import matplotlib.pyplot as plt
from sklearn import metrics

numpy.random.seed(2)

# L'eix x representa el nombre de minuts abans de fer una compra.
# L'eix y representa la quantitat de diners gastada en la compra.
x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

myline = numpy.linspace(0, 6, 100)

plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
#Multiple scatter plots in single plot in Pandas using Matplotlib.
import pandas as pd
 
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler

df=pd.read_csv("./dat/insurance.csv")
df= df.dropna()
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
def sex_to_num(x):
    return(0 if x=='male' else 1)

def smoker_to_num(x):
    return (0 if x =='no' else 1)

df['sex_num'] = df['sex'].map(sex_to_num)
df['smok_num']=df['smoker'].map(smoker_to_num)

# %%
df['smoker']=df['smoker'].map({'yes':0,'no':1})

# %%
#Finding correlation between age,bmi,children,smoker and sex.
X=df[['age','bmi','children','smok_num','sex_num']]
y=df['charges']

regr= linear_model.LinearRegression()
scale = StandardScaler()
scaledX = scale.fit_transform(X.values)
regr.fit(scaledX,y)
# Out:
# LinearRegression()

# %%
regr.score(scaledX,y)
# Out:
# 0.7497225098709179

# %%
print(regr.predict(X))
# Out:
# [146551.31004359 145360.25076771 181188.6217839  ... 150905.39739967
#  140050.4537456  300882.62220425]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
regr.coef_
# Out:
# array([3619.81291097, 1965.10247846,  571.68540744, 9613.76691516,
#          64.31640574])

# %%
r2_score(y, regr.predict(scaledX))
# Out:
# 0.7497225098709179

# %%
scaled[0]
# Out:
# array([-1.50996545, 25.64647356])

# %%
#Multiple scatter plots in single plot in Pandas using Matplotlib.

# %%
import pandas as pd
 
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
 
df=pd.read_csv(".dat/insurance.csv")
df= df.dropna()
df.head()

# %%
color = df['sex'].apply(lambda x: 'navy' if x == 'male' else 'gold')
bcolor = df['smoker'].apply(lambda x: 'red' if x == 'yes' else 'green')
 
figure(figsize=(10, 8), dpi=80)
 
plt.style.use('ggplot')
 
plt.title('Relation between age,bmi and charges')
plt.xlabel('age and bmi')
plt.ylabel('charges')
plt.scatter(x=df['age'],y=df['charges'],s=100,c=color,alpha=0.6,marker='o',edgecolors=bcolor,linewidth=df['children'])
plt.scatter(x=df['bmi'],y=df['charges'],s=100,c=color,alpha=0.5,marker='h',edgecolors=bcolor,linewidth=df['children'])
 
plt.legend(loc='upper right')
  
plt.tight_layout()
 
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Mostra les dades pel conjunt de test
#

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)
x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x
train_x = x[:80]
train_y = y[:80]
test_x = x[80:]
test_y = y[80:]
mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))
myline = numpy.linspace(0, 6, 100)
plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
plt.scatter(test_x, test_y)
plt.show()

# %%
# Fes una predicció de despesa per un temps de 5 minuts

# %%
# Destaca el punt a la gràfica

# %%
# Repeteix tot l'experiment fent que la mostra sigui de 180 elements. 
# Ves en compte al decidir la mida del conjunt d'entrenament i la de test
# Compara els resultats obtinguts amb els resultats anteriors
from sklearn import model_selection as ms

X_train, X_test, y_train, y_test = ms.train_test_split(
                                          x, y, test_size=0.20, random_state=42)

# %%
print (len(X_train), len(X_test))
# Out:
# 80 20

# %%
#Model Mercè

# %%
def sex_to_num(x):
    return(0 if x=='male' else 1)

def smoker_to_num(x):
    return (0 if x =='no' else 1)

df['sex_num'] = df['sex'].map(sex_to_num)
df['smok_num']=df['smoker'].map(smoker_to_num)

# %%
df['smoker']=df['smoker'].map({'yes':0,'no':1})

# %%
X=df[['age','bmi','children','smok_num','sex_num']]
y=df['charges']

regr= linear_model.LinearRegression()
scale = StandardScaler()
scaledX = scale.fit_transform(X.values)
regr.fit(scaledX,y)
# Out:
# LinearRegression()

# %%
regr.score(scaledX,y)
# Out:
# 0.7497225098709179

# %%
print(regr.predict(X))
# Out:
# [146551.31004359 145360.25076771 181188.6217839  ... 150905.39739967
#  140050.4537456  300882.62220425]
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
regr.coef_
# Out:
# array([3619.81291097, 1965.10247846,  571.68540744, 9613.76691516,
#          64.31640574])

# %%
regr.score(scaledX,y)
# Out:
# 0.7497225098709179
